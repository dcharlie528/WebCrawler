# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

URL = 'https://www.ettoday.net/news/focus/%E6%94%BF%E6%B2%BB/' #爬ettoday
req = requests.get(URL)
print(req.status_code)
inside = req.text
print(inside)
# Out:
# 200
# <!doctype html>
# <html lang="zh-Hant" prefix="og:http://ogp.me/ns#" xmlns:wb="http://open.weibo.com/wb" itemscope itemtype="http://schema.org/WebSite">
# <head>
# <meta charset="utf-8">
# <!-- ★★★以下非共用★★★ 開始 -->
# <meta name="robots" content="noarchive"/>
# <title>ETtoday政治新聞 | ETtoday新聞雲</title>
# <link rel="canonical" href="https://www.ettoday.net/news/focus/政治/"/>
#
# <!-- 網頁社群分享meta 開始 -->
# <meta property="og:url" itemprop="url" content="https://www.ettoday.net/news/focus/政治/"/>
# <meta property="og:title" itemprop="name" content="政治新聞 | ETtoday新聞雲"/>
# <meta property="og:image" itemprop="image" content="https://cdn2.ettoday.net/style/ettoday2017/images/push.jpg"/>
# <meta property="og:image:width" content="1200"/>
# <meta property="og:image:height" content="628"/>
# <meta property="og:type" content="article"/>
# <meta name="description" content="《ETtoday新聞雲》政治新聞最新列表" />
# <meta property="og:description" itemprop="description" content="《ETtoday新聞雲》政治新聞最新列表"/>
# ...

# %%
from bs4 import BeautifulSoup as bs

t = bs(req.text, 'html.parser')
title = t.select('div.piece.clearfix a')
print(title)
# Out:
# [<a class="pic" href="/news/20200702/1751079.htm" title="6日綁定數位三倍券抽Gogoro　經濟部再找銀行業者談「加碼」"><img alt="6日綁定數位三倍券抽Gogoro　經濟部再找銀行業者談「加碼」" data-original="//cdn2.ettoday.net/images/4976/c4976165.jpg" src="//cdn2.ettoday.net/style/ettoday2017/images/loading_200x150.gif"/></a>, <a href="/news/20200702/1751079.htm" title="6日綁定數位三倍券抽Gogoro　經濟部再找銀行業者談「加碼」">6日綁定數位三倍券抽Gogoro　經濟部再找銀行業者談「加碼」</a>, <a class="pic" href="/news/20200702/1751055.htm" title="港區國安法實施　鄭文燦：歡迎港人來台居住，建立友善制度"><img alt="港區國安法實施　鄭文燦：歡迎港人來台居住，建立友善制度" data-original="//cdn2.ettoday.net/images/4976/c4976290.jpg" src="//cdn2.ettoday.net/style/ettoday2017/images/loading_200x150.gif"/></a>, <a href="/news/20200702/1751055.htm" title="港區國安法實施　鄭文燦：歡迎港人來台居住，建立友善制度">港區國安法實施　鄭文燦：歡迎港人來台居住，建立友善制度</a>, <a class="pic" href="/news/20200702/1751061.htm" title="對岸酸台灣、索馬利蘭「半斤、八兩想建交」　外交部：酸葡萄"><img alt="對岸酸台灣、索馬利蘭「半斤、八兩想建交」　外交部：酸葡萄" data-original="//cdn2.ettoday.net/images/4974/c4974475.jpg" src="//cdn2.ettoday.net/style/ettoday2017/images/loading_200x
# ...

# %%
print(title[0]['href'])
print(URL+title[0]['href'])
# Out:
# /news/20200702/1751079.htm
# https://www.ettoday.net/news/focus/%E6%94%BF%E6%B2%BB//news/20200702/1751079.htm

# %%
pick_title = [i.text for i in title]
print(pick_title)
# Out:
# ['精彩專題', '熱門活動', '農田水利10月起官派\u3000前綠中常委砲轟', '1民進黨這樣都OK？蔡壁如嘆年輕人跟風流行32分鐘前', '2陳菊週五拜會立法院\u3000「藍白」拒見、時代力量公開會談48分鐘前', '3遭諷戰鬥力薄弱...林為洲：面對鎖喉功你能撐多久？57分鐘前', '政治熱門新聞', '\n\n\t\t\t\t\t\t\t\t\t\t\t\t<!-- <![CDATA[\n\t\t\t\t\t\t\t\t\t\t\t\tvar ts = Math.random();\n\t\t\t\t\t\t\t\t\t\t\t\tdocument.write(\'<scr\' + \'ipt language="JavaScript" type="text/javascript" src="//ad.ettoday.net/ads.php?bid=news_text_4&rr=\'+ ts +\'"></scr\' + \'ipt>\');\n\t\t\t\t\t\t\t\t\t\t\t\t// ]]> -->\n\t\t\t\t\t\t\t\t\t\t\t\t\n', '三倍券政府沒想到這點\u3000黃暐瀚驚呆', '3種身份綁悠遊付「花3000補3000」', '陳其邁支持度過半\u3000名嘴給李眉蓁建議', '179萬完成申購三倍券！6成選紙本', '國民黨：領三倍券排隊耗時\u3000網： 不要領啊', '王定宇：國民黨練拳可找館長當黨主席', '王浩宇是「潔西卡」？急po證據否認', '\n\n\t\t\t\t\t\t\t\t\t\t\t\t<!-- <![CDATA[\n\t\t\t\t\t\t\t\t\t\t\t\tvar ts = Math.random();\n\t\t\t\t\t\t\t\t\t\t\t\tdocument.write(\'<scr\' + \'ipt language="JavaScript" type="text/javascript" src="//ad.ettoday.net/ads.php?bid=news_text_5&rr=\'+ ts +\'"></scr\' + \'ipt>\');\n\t\t\t\t\t\t\t\t\t\t\t\t// ]]> -->\n\t\t\t\t\t\t\t\
# ...

# %%
print(pick_title[2])
print(re.findall("10.+",pick_title[2]))
# Out:
# 農田水利10月起官派　前綠中常委砲轟
# ['10月起官派\u3000前綠中常委砲轟']

# %%
import re

for i in pick_title:
    print(re.findall(".+三倍.+",i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-10607d3890b1> in <module>
#       1 import re
#       2
# ----> 3 for i in pick_title:
#       4     print(re.findall(".+三倍.+",i))
#
# NameError: name 'pick_title' is not defined

# %%
# print(len(pick_title))
threebay = []
x = 0
for x in pick_title:
    if "三倍" in x:
        threebay.append(x)
        
print(threebay)
print("今天關於三倍卷的新聞有" + str(len(threebay)) + "筆")
# Out:
# ['三倍券政府沒想到這點\u3000黃暐瀚驚呆', '179萬完成申購三倍券！6成選紙本', '國民黨：領三倍券排隊耗時\u3000網： 不要領啊', '振興三倍券怎麼用？\u3000一次看懂「四種使用攻略」', '新北加碼！侯友宜推「500元三倍券換800元地方券」', '6日綁定數位三倍券抽Gogoro\u3000經濟部再找銀行業者談「加碼」', '振興三倍券預定已完成216萬件\u3000紙本佔64％、數位35％', '1200萬份紙本三倍券不夠發？\u3000行政院：觀察後再考量加印', '三倍券政府沒想到這點\u3000黃暐瀚驚呆']
# 今天有關三倍卷的新聞有9筆

# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import chardet
URL = 'https://www3.nhk.or.jp/news/cat06.html?utm_int=all_header_menu_news-international'
aaa = requests.get(URL)
print(aaa.status_code)
chardet.detect(URL)
# inside = aaa.text.encode('GBK')
# print(inside)
# Out:
# 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a8eedf77bf38> in <module>
#       4 aaa = requests.get(URL)
#       5 print(aaa.status_code)
# ----> 6 chardet.detect(URL)
#       7 # inside = aaa.text.encode('GBK')
#       8 # print(inside)
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      32         if not isinstance(byte_str, bytes):
#      33             raise TypeError('Expected object of type bytes or bytearray, got: '
# ---> 34                             '{0}'.format(type(byte_str)))
#      35         else:
#      36             byte_str = bytearray(byte_str)
#
# TypeError: Expected object of type bytes or bytearray, got: <class 'str'>
